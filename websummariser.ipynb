# %%
import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
from openai import OpenAI
openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
message = "Hello, Llama! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(model="llama3.2", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)
# Out:
# Hey there! Welcome! I'm thrilled to be your first conversational partner. I'm excited to chat with you and help with any questions or topics you'd like to discuss. How's your day going so far? Is there something specific on your mind that you'd like to talk about, or do you just want to get to know me a bit?

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
system_prompt = " You are a creepy yet fun Story telling Assistant who does not harm anyone but makes everyone smile. You will be given a website url and you have to analyze and prepare a summary of the urlcontents for your story and even if it is a boring website make the user engage with it because of your out of the box summary"
def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
def summarize(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model = "llama3.2",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://mongodb.com/docs/")
# Out:
# '# Welcome to the Vibrant World of MongoDB!\n==========================\n\nIn the vast ocean of database solutions, **MongoDB** emerges as a shining star – a document-oriented, operational database built for modern applications. Its unique approach allows developers to store rich JSON-like documents that mirror their code\'s objects.\n\n## Get Ready to Unlock the Power of MongoDB!\n\n`"{\n"name": "Grace Hopper",\n"occupations": ["Computer Scientist", "Mathematician", "Professor"],\n"location": {\n(city: "Arlington", state: "Virginia", zip: "22202")\n}"`\n\nThis is just a taste of what MongoDB has to offer. With its robust features, developers can:\n\nStrongly Consistent Data with ACID transactions\nModern query capabilities like geospatial search and vector search\nServerless Scaling for Horizontal Fault Tolerance\n\n## Dive into the World of MongoDB Documentation!\n\nThe documentation is organized into four main sections: \n\n*   **Get Started**: Deploy your first database and downl
# ...

# %%
print(summarize("https://cnn.com"))
# Out:
# **Summary of CNN Website in Markdown**
#
# # About This Website
#
# *   A global leader in breaking news, userving reliable and timely information to our diverse audience.
#
# ### Features
#
# *   **News**: Breaking news updates 24/7
# *   **Politics**: US news, International Affairs, Election coverage and more.
# *   **Business**:  Market News, Investing Analysis and Company Updates.
# *   **World Cup**: Live Scores, Match Results, and Analysis.
# *   **Weather**: National Weather Service forecasts, and Real-time weather updates.
#
# ### Content Themes
#
# *   World
# *   Politics
# *   Business
# *   Entertainment
# *   Style
# *   Travel
# *   Sports
# *   Science
# *   Climate
# *   Health & Wellness
# *   Technology
# *   Lifestyle
#
# ### Shows
# Shows A-Z include:
# 1.  CNN 10
# 2.  The Assignment with Audie Cornish
# 3.     All There Is with Anderson Cooper
# 4.    Chasing Life with Dr. Sanjay Gupta
#
# Here's a summary of the top stories on CNN:
#
# **Top Stories**
#
# ...
